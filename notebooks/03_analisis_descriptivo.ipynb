# %% [markdown]
# # 03 — Análisis descriptivo
#
# **Propósito:** estadísticas descriptivas del dataset analítico consolidado
# (`data/03_primary/dataset_analitico.parquet`): evolución por tipo de delito,
# ranking de localidades, correlaciones con contexto DANE. *Pendiente de desarrollo.*

# %% [markdown]
# # 02 — Limpieza y transformación
#
# **Propósito:** documentar/ilustrar las reglas de limpieza y normalización aplicadas por
# `src/data_cleaning.py` y el cruce por código de localidad de `src/pipeline_integration.py`.
# *Pendiente de desarrollo — la lógica productiva ya vive en `src/`.*

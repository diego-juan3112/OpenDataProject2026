# %% [markdown]
# # 04 — Modelo predictivo
#
# **Propósito:** experimentación del modelo de riesgo (Random Forest / Gradient Boosting)
# con manejo del desbalance de clases y validación espacio-temporal sin fuga
# (train ≤2024, test 2025). *Pendiente de desarrollo — Integrante 2.*

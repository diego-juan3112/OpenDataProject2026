# %% [markdown]
# # 05 — Reportes automáticos
#
# **Propósito:** generación de figuras y tablas para `reports/` (distribuciones,
# correlaciones, matriz de confusión) y del reporte final. *Pendiente de desarrollo.*
